# %% [markdown]
# <a href="https://colab.research.google.com/github/kuruvajayanth12/Neural-Networks-and-Deep-Learning/blob/main/NNDL_Notes_CNNipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread("tiger_2.jpg")

# Convert BGR (OpenCV default) to RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Split into R, G, B channels
R = image_rgb[:, :, 0]
G = image_rgb[:, :, 1]
B = image_rgb[:, :, 2]

# Print matrices
print("Red Matrix:\n", R)
print("\nGreen Matrix:\n", G)
print("\nBlue Matrix:\n", B)

# Display the image and channels
plt.figure(figsize=(10,8))

plt.subplot(2,2,1)
plt.imshow(image_rgb)
plt.title("Original Image")
plt.axis("off")

plt.subplot(2,2,2)
plt.imshow(R, cmap='Reds')
plt.title("Red Channel")
plt.axis("off")

plt.subplot(2,2,3)
plt.imshow(G, cmap='Greens')
plt.title("Green Channel")
plt.axis("off")

plt.subplot(2,2,4)
plt.imshow(B, cmap='Blues')
plt.title("Blue Channel")
plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# Red Matrix:
#  [[162 162 163 ...  76  70  70]
#  [162 162 163 ...  68  68  70]
#  [162 162 163 ...  61  68  76]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
#
# Green Matrix:
#  [[174 174 175 ...  99  95  95]
#  [174 174 175 ...  91  91  95]
#  [174 174 175 ...  84  91  99]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
#
# Blue Matrix:
#  [[162 162 163 ...  83  76  76]
#  [162 162 163 ...  75  73  76]
#  [162 162 163 ...  68  73  81]
#  ...
#  [253 253 253 ... 255 255 255]
#  [253 253 253 ... 255 255 255]
#  [253 253 253 ... 255 255 255]]

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load image
image = cv2.imread("tiger_2.jpg")

# Convert BGR to RGB for displaying
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# 1️⃣ Blur Image (Gaussian Blur)
blurred = cv2.GaussianBlur(image_rgb, (15, 15), 0)

# 2️⃣ Sharpen Image
kernel = np.array([[0, -1, 0],
                   [-1, 5, -1],
                   [0, -1, 0]])

sharpened = cv2.filter2D(image_rgb, -1, kernel)

# 3️⃣ Edge Detection (Canny)
edges = cv2.Canny(image, 100, 200)

# Display Results
plt.figure(figsize=(10,8))

plt.subplot(2,2,1)
plt.imshow(image_rgb)
plt.title("Original Image")
plt.axis("off")

plt.subplot(2,2,2)
plt.imshow(blurred)
plt.title("Blurred Image")
plt.axis("off")

plt.subplot(2,2,3)
plt.imshow(sharpened)
plt.title("Sharpened Image")
plt.axis("off")

plt.subplot(2,2,4)
plt.imshow(edges, cmap='gray')
plt.title("Edge Detection")
plt.axis("off")

plt.tight_layout()
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load grayscale image
gray = cv2.imread("tiger.jpg", cv2.IMREAD_GRAYSCALE)

# Apply color map (this adds visible colors)
color_image = cv2.applyColorMap(gray, cv2.COLORMAP_JET)

# Convert BGR to RGB for display
color_image_rgb = cv2.cvtColor(color_image, cv2.COLOR_BGR2RGB)

# Display both
plt.figure(figsize=(8,5))

plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.title("Grayscale Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(color_image_rgb)
plt.title("Color Image (False Color)")
plt.axis("off")

plt.tight_layout()
plt.show()

# %%
import cv2

# Load image in grayscale
gray = cv2.imread("tiger.jpg", cv2.IMREAD_GRAYSCALE)

# Print full pixel matrix
print("Grayscale Pixel Matrix:\n")
print(gray)
# Out:
# Grayscale Pixel Matrix:
#
# [[  7   8   8 ...   5   5   5]
#  [  6   7   7 ...   5   5   5]
#  [  5   6   6 ...   5   5   5]
#  ...
#  [102 126 115 ...  65  65  67]
#  [122 149 146 ...  67  65  66]
#  [162 150 144 ...  68  65  66]]
